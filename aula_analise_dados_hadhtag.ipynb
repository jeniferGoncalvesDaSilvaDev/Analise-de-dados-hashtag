# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferGoncalvesDaSilvaDev/Analise-de-dados-hashtag/blob/main/aula_analise_dados_hadhtag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/ClientesBanco.csv',sep ='|' , encoding='latin-1')
display(df)
# Out:
#       CLIENTNUM,Categoria,Idade,Sexo,Dependentes,Educação,Estado Civil,Faixa Salarial Anual,Categoria Cartão,Meses como Cliente,Produtos Contratados,Inatividade 12m,Contatos 12m,Limite,Limite Consumido,Limite Disponível,Mudanças Transacoes_Q4_Q1,Valor Transacoes 12m,Qtde Transacoes 12m,Mudança Qtde Transações_Q4_Q1,Taxa de Utilização Cartão
# 0      768805383,Cliente,45,M,3,Ensino Médio,Casado,$...
# 1      818770008,Cliente,49,F,5,Ensino Superior,Solte...
# 2      713982108,Cliente,51,M,3,Ensino Superior,Casad...
# 3      769911858,Cliente,40,F,4,Ensino Médio,Não info...
# 4      709106358,Cliente,40,M,3,Sem ensino formal,Cas...
# ...                                                  ...
# 10122  772366833,Cliente,50,M,2,Ensino Superior,Solte...
# 10123  710638233,Cancelado,41,M,2,Não informado,Divor...
# 10124  716506083,Cancelado,44,F,1,Ensino Médio,Casado...
# 10125  717406983,Cancelado,30,M,2,Ensino Superior,Não...
# 10126  714337233,Cancelado,43,F,2,Ensino Superior,Cas...
#
# ...

# %%
display(df.head(5))
# Out:
#   CLIENTNUM,Categoria,Idade,Sexo,Dependentes,Educação,Estado Civil,Faixa Salarial Anual,Categoria Cartão,Meses como Cliente,Produtos Contratados,Inatividade 12m,Contatos 12m,Limite,Limite Consumido,Limite Disponível,Mudanças Transacoes_Q4_Q1,Valor Transacoes 12m,Qtde Transacoes 12m,Mudança Qtde Transações_Q4_Q1,Taxa de Utilização Cartão
# 0  768805383,Cliente,45,M,3,Ensino Médio,Casado,$...
# 1  818770008,Cliente,49,F,5,Ensino Superior,Solte...
# 2  713982108,Cliente,51,M,3,Ensino Superior,Casad...
# 3  769911858,Cliente,40,F,4,Ensino Médio,Não info...
# 4  709106358,Cliente,40,M,3,Sem ensino formal,Cas...
